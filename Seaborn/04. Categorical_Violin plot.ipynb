# %%
"""
Violin Plot adalah gabungan dari box plot dan density plot. 
Violin plot menggambarkan distribusi data dan juga menggambarkan distribusi data pada setiap level kategori. 
Violin plot biasanya digunakan untuk membandingkan distribusi data pada beberapa level kategori.
Violin plot dapat digambarkan dengan menggunakan fungsi `violinplot()` dari library seaborn. 
Berikut adalah contoh penggunaan violin plot untuk membandingkan distribusi data pada beberapa level kategori.
"""
import seaborn as sns
import pandas as pd
df = pd.read_excel("./src/supermarket_sales.xlsx")
df.head(3)
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
#
#        Payment    cogs  gross margin percentage  gross income  Rating
# 0  Credit card  164.52                 4.761905         8.226     5.9
# 1      Ewallet   57.92                 4.761905         2.896     4.5
# 2         Cash  102.04                 4.761905         5.102     6.8

# %% [markdown]
# ## Basic Violin Plot

# %%
sns.violinplot(y="Total",data=df)
# Out:
# <Axes: ylabel='Total'>

# %% [markdown]
# ## Violin Plot two categorical

# %%
sns.violinplot(data=df,x="Payment",y="Total",palette="muted",hue="Gender")
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ## Change Violinlot to horizontalline

# %%
sns.violinplot(x="Payment",y="Total",hue="Gender",data=df,palette="muted",inner="quartile",split=True)
#paamerter split=True digunakan untuk memisahkan distribusi data pada setiap level kategori
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
sns.violinplot(x="Payment",y="Total",hue="Gender",data=df,palette="muted",inner="stick",split=True,bw= 0.1)
#fungsi parameter bw digunakan untuk mengatur lebar distribusi data pada violin plot
#semakin kecil nilai bw maka distribusi data akan semakin lebar
#semakin besar nilai bw maka distribusi data akan semakin sempit
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16076\311363327.py:1: FutureWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.1`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.
#
#   sns.violinplot(x="Payment",y="Total",hue="Gender",data=df,palette="muted",inner="stick",split=True,bw= 0.1)
# <Axes: xlabel='Payment', ylabel='Total'>
